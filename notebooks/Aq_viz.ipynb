# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
csv_path = '../data/AQI_Pre.csv'

df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#          Date   PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2      O3  \
# 0  2015-01-29   83.13   NaN   6.93  28.71  33.72  NaN   6.93  49.52   59.76
# 1  2015-01-30   79.84   NaN  13.85  28.68  41.08  NaN  13.85  48.49   97.07
# 2  2015-01-31   94.52   NaN  24.39  32.66  52.61  NaN  24.39  67.39  111.33
# 3  2015-02-01  135.99   NaN  43.48  42.08  84.57  NaN  43.48  75.23  102.70
# 4  2015-02-02  178.33   NaN  54.56  35.31  72.80  NaN  54.56  55.04  107.38
#
#    ...  City_Kochi  City_Kolkata  City_Lucknow  City_Mumbai  City_Patna  \
# 0  ...       False         False         False        False       False
# 1  ...       False         False         False        False       False
# 2  ...       False         False         False        False       False
# 3  ...       False         False         False        False       False
# 4  ...       False         False         False        False       False
#
# ...

# %%
df=df.dropna()

# %%
df.head()
# Out:
#             Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO    SO2  \
# 1445  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12  15.24
# 1446  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14  26.96
# 1447  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11  33.59
# 1448  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09  19.00
# 1449  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25  0.16  10.55
#
#           O3  ...  City_Kochi  City_Kolkata  City_Lucknow  City_Mumbai  \
# 1445  127.09  ...       False         False         False        False
# 1446  117.44  ...       False         False         False        False
# 1447  111.81  ...       False         False         False        False
# 1448  138.18  ...       False         False         False        False
# 1449  109.74  ...       False         False         False        False
#
#       City_Patna  City_Shillong  City_Talcher  City_Thiruvananthapuram  \
# ...

# %%
df.tail()
# Out:
#              Date  PM2.5   PM10    NO    NO2    NOx    NH3    CO    SO2  \
# 24844  2020-06-26   7.63  32.27  5.91  23.27  17.19  11.15  0.46   6.87
# 24845  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47  0.47   8.55
# 24846  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99  0.52  12.72
# 24847  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71  0.48   8.42
# 24848  2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03  0.52   9.84
#
#           O3  ...  City_Kochi  City_Kolkata  City_Lucknow  City_Mumbai  \
# 24844  19.90  ...       False         False         False        False
# 24845  23.30  ...       False         False         False        False
# 24846  30.14  ...       False         False         False        False
# 24847  30.96  ...       False         False         False        False
# 24848  28.30  ...       False         False         False        False
#
#        City_Patna  City_Shillong  City_Talcher  City_Thiruvananthapuram  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6236 entries, 1445 to 24848
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     6236 non-null   object
#  1   PM2.5                    6236 non-null   float64
#  2   PM10                     6236 non-null   float64
#  3   NO                       6236 non-null   float64
#  4   NO2                      6236 non-null   float64
#  5   NOx                      6236 non-null   float64
#  6   NH3                      6236 non-null   float64
#  7   CO                       6236 non-null   float64
#  8   SO2                      6236 non-null   float64
#  9   O3                       6236 non-null   float64
#  10  Benzene                  6236 non-null   float64
#  11  Toluene                  6236 non-null   float64
#  12  Xylene                   6236 non-null   float64
# ...

# %%
# Assuming df is your original DataFrame
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# Create a new DataFrame with only numeric columns
numeric_df = df[numeric_columns.columns]

# Display the new DataFrame
print(numeric_df.head())
# Out:
#       PM2.5    PM10    NO    NO2    NOx    NH3    CO    SO2      O3  Benzene  \
# 1445  81.40  124.50  1.44  20.50  12.08  10.72  0.12  15.24  127.09     0.20
# 1446  78.32  129.06  1.26  26.00  14.85  10.28  0.14  26.96  117.44     0.22
# 1447  88.76  135.32  6.60  30.85  21.77  12.91  0.11  33.59  111.81     0.29
# 1448  64.18  104.09  2.56  28.07  17.01  11.42  0.09  19.00  138.18     0.17
# 1449  72.47  114.84  5.23  23.20  16.59  12.25  0.16  10.55  109.74     0.21
#
#       Toluene  Xylene    AQI  Month
# 1445     6.50    0.06  184.0     11
# 1446     7.95    0.08  197.0     11
# 1447     7.63    0.12  198.0     11
# 1448     5.02    0.07  188.0     11
# 1449     4.71    0.08  173.0     11

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
df = df.drop('PM2.5', axis=1)

# %%
#df=df.drop('Month',axis=1)
df=df.drop('Date',axis=1)

# %%
# Sum up occurrences of each city across all one-hot encoded columns
city_distribution = df.iloc[:, 14:40].sum()

# Plot the city distribution
plt.figure(figsize=(12, 6))
city_distribution.plot(kind='bar', color='skyblue')
plt.title('City Distribution')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of chemical parameters
chemical_parameters = ['PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']

# Plot scatter plots for each chemical parameter against AQI
plt.figure(figsize=(15, 15))
for parameter in chemical_parameters:
    plt.subplot(4, 3, chemical_parameters.index(parameter) + 1)
    sns.scatterplot(x=parameter, y='AQI', data=df, alpha=0.5)
    plt.title(f'AQI vs {parameter}')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[chemical_parameters + ['AQI']])
plt.title('Box Plot for Chemical Parameters and AQI')
plt.xticks(rotation=45)
plt.show()

# %%
df1=pd.read_csv('AQI_Pre.csv')

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='AQI', data=df1)
plt.title('AQI Over Time')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Bar plot for average AQI across different months
plt.figure(figsize=(12, 6))
sns.barplot(x='Month', y='AQI', data=df1)
plt.title('Average AQI Across Months')
plt.xlabel('Month')
plt.ylabel('Average AQI')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert 'Date' column to datetime format
df1['Date'] = pd.to_datetime(df1['Date'])

# Extracting the year from the 'Date' column
df1['Year'] = df1['Date'].dt.year

# Line plot for AQI variation across months over the years
plt.figure(figsize=(14, 8))
sns.lineplot(x='Month', y='AQI', hue='Year', data=df1, ci=None)
plt.title('AQI Variation Across Months Over the Years')
plt.xlabel('Month')
plt.ylabel('AQI')
plt.legend(title='Year', loc='upper right', bbox_to_anchor=(1.15, 1))
plt.show()
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_38224\3916221529.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Month', y='AQI', hue='Year', data=df1, ci=None)
